# %% [markdown]
# ![pic2.png](data:image/png;base64,...)

# %% [markdown]
# $x_2$ and $x_4$ are URS so it can be written as:
# $x_2 = x_2^{+} - x_2^{-}$ and $x_4 = x_4^{+} - x_4^{-}$; $x_2^{+},x_2^{-},x_4^{+},x_4^{-} \geq 0$
